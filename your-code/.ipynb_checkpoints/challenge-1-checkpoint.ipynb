# %%
print('Welcome to this calculator!')
print('It can add and subtract whole numbers from zero to five')

a = input('Please choose your first number (zero to five): ')
b = input('What do you want to do? plus or minus: ')
c = input('Please choose your second number (zero to five): ')

'''
L.S. Correct approach! Still quite long, but very readable. Could you also do it without all the if-statements?


'''

def calculation(a,b,c):
    if a == 'zero':
        a = 0 
    elif a == 'one':
        a = 1
    elif a == 'two':
        a = 2
    elif a == 'three':
        a = 3
    elif a == 'four':
        a = 4
    elif a == 'five':
        a = 5

    if c == 'zero':
        c = 0 
    elif c == 'one':
        c = 1
    elif c == 'two':
        c = 2
    elif c == 'three':
        c = 3
    elif c == 'four':
        c = 4
    elif c == 'five':
        c = 5
    
    
    if b == 'minus':
        return a-c
    elif b == 'plus':
        return a+c
    
def number_to_word(x):
    if x == 0:
        return 'zero'
    elif x == 1:
        return 'one'
    elif x == 2:
        return 'two'
    elif x == 3:
        return 'three'
    elif x == 4:
        return 'four'
    elif x == 5:
        return 'five'
    elif x == 6:
        return 'six'  
    elif x == 7:
        return 'seven'
    elif x == 8:
        return 'eight'
    elif x == 9:
        return 'nine'
    elif x == 10:
        return 'ten'
    
    '''
    L.S. This works, but goes only until -5. Is there a way to make this code more generic so that
    you can input any negative number? 
    '''
    
    elif x == -1:
        return 'minus one'
    elif x == -2:
        return 'minus two'
    elif x == -3:
        return 'minus three'
    elif x == -4:
        return 'minus four'
    elif x == -5:
        return 'minus five'


x = calculation(a, b, c)

'''
L.S. Well done! Very good to make two functions, each with a different task.
'''
y = number_to_word(x)

print(a, b, c, 'is', y)
print("Thanks for using this calculator, goodbye :)")
# Out:
# Welcome to this calculator!
# It can add and subtract whole numbers from zero to five
# Please choose your first number (zero to five): five
# What do you want to do? plus or minus: minnus
# Please choose your second number (zero to five): zero
# five minnus zero is None
# Thanks for using this calculator, goodbye :)
